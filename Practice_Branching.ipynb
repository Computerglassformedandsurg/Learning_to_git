# %% [markdown]
# <a href="https://colab.research.google.com/github/Computerglassformedandsurg/Learning_to_git/blob/main/Practice_Branching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('image.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=292x220>
